# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import re
import os
import shutil
import seaborn as sns
from scipy import stats
from ptm_dict import modres
# from sklearn.metrics import mean_squared_error
# from math import sqrt
# from sklearn.metrics import mean_absolute_error as mae

# %%
# Block of seaborn style settings
plt.rc('font', size=23) #controls default text size
plt.rc('axes', labelsize=20) #fontsize of the x and y labels
plt.rc('xtick', labelsize=18) #fontsize of the x tick labels
plt.rc('ytick', labelsize=18) #fontsize of the y tick labels
sns.set(style='whitegrid', color_codes=True, font='serif', font_scale=2)

plt.rc('font', size=23) #controls default text size
plt.rc('xtick', labelsize=25) #fontsize of the x tick labels
plt.rc('ytick', labelsize=25) #fontsize of the y tick labels

# %%
skempi2 = pd.read_csv('/groups/sbinlab/panf/SKEMPIv2_benchmark/skempi2_final.csv')
skempi2_raw = pd.read_csv('/groups/sbinlab/panf/SKEMPIv2_benchmark/skempi_v2.csv', sep=';')
skempi2_avg_nb = pd.read_csv('/groups/sbinlab/panf/SKEMPIv2_benchmark/skempi2_nb.csv')

# %%
exp_cart_ddG_all = pd.read_csv('/groups/sbinlab/panf/SKEMPIv2_benchmark/cart_pipeline_full_struct.csv')

# %%
exp_cart_ddG_nb = pd.read_csv('/groups/sbinlab/panf/SKEMPIv2_benchmark/cart_pipeline_full_struct_nb_inc.csv')

# %%
exp_flex_ddG = pd.read_csv('flex_ddg_reg_skempi2_new.csv')

# %%
exp_cart_ddG_nb

# %%
exp_cart_ddG_all_nb = pd.concat([exp_cart_ddG_all, exp_cart_ddG_nb])

# %%
exp_cart_ddG_all_nb.loc[exp_cart_ddG_all_nb.duplicated(subset=['#Pdb', 'Mutation(s)_PDB'], keep=False)]
# Out:
#                             variant  mean_ddG   std_ddG  mean_ddG_infc  \
# 186                           Y304A  4.159770  0.014280       0.940453
# 551                           T756S  0.845517  0.000000       0.975309
# 1699                          K525A  1.513448  0.022295       0.958092
# 3033                          Y379A  4.295402  0.002834       2.978370
# 3076                           R65A  1.565517  0.002395       0.642604
# 3092                          Y382A  0.622874  0.005975       0.557986
# 3173                           K66A -0.040920  0.089995      -0.569395
# 3780        M416V:A418T:G503E:A545V  9.676437  0.070773       1.667140
# 4012    M4L:T241D:N244H:H314Y:S318T -2.452989  0.105355      -2.256503
# 4013  L192M:D429T:H432N:Y502H:T506S  5.459885  0.171013       2.555709
# 7                             Y304A  4.159770  0.014280       0.940453
# 84                            K525A  1.513448  0.022295       0.958092
# 107                           Y379A  4.295402  0.002834       2.978370
# 110                           Y382A  0.622874  0.005975       0.557986
# 141                            R65A  1.565517  0.002395       0.642604
# 142                            K66A -0.040920  0.089995      -0.569395
# 219         M416V:A418T:G503E:A545V  9.676437  0.070773       1.667140
# 243                           T756S  0.845517  0.000000       0.975309
# 262     M4L:T241D:N244H:H314Y:S318T -2.452989  0.105355      -2.256503
# 263   L192M:D429T:H432N:Y502H:T506S  5.459885  0.171013       2.555709
#
#       std_ddG_infc PDB_ID  index    case_ID         #Pdb  \
# 186       0.005423   1JCK    186   186_1JCK     1JCK_A_B
# 551       0.010475   2AJF    551   551_2AJF     2AJF_A_E
# 1699      0.024549   3HFM   1699  1699_3HFM    3HFM_HL_Y
# 3033      0.008402   1BD2   3033  3033_1BD2  1BD2_ABC_DE
# 3076      0.009089   1AO7   3076  3076_1AO7  1AO7_ABC_DE
# 3092      3.150254   1AO7   3092  3092_1AO7  1AO7_ABC_DE
# 3173      0.180660   1AO7   3173  3173_1AO7  1AO7_ABC_DE
# 3780      0.132203   4K71   3780  3780_4K71    4K71_A_BC
# 4012      0.010830   1BJ1   4012  4012_1BJ1   1BJ1_HL_VW
# 4013      0.341152   1CZ8   4013  4013_1CZ8   1CZ8_HL_VW
# 7         0.005423   1JCK    230        NaN     1JCK_A_B
# 84        0.024549   3HFM   2260        NaN    3HFM_HL_Y
# 107       0.008402   1BD2   3804        NaN  1BD2_ABC_DE
# 110       3.150254   1AO7   3825        NaN  1AO7_ABC_DE
# 141       0.009089   1AO7   3939        NaN  1AO7_ABC_DE
# 142       0.180660   1AO7   3940        NaN  1AO7_ABC_DE
# 219       0.132203   4K71   4578        NaN    4K71_A_BC
# 243       0.010475   2AJF   4721        NaN     2AJF_A_E
# 262       0.010830   1BJ1   4867        NaN   1BJ1_HL_VW
# 263       0.341152   1CZ8   4869        NaN   1CZ8_HL_VW
#
#                      Mutation(s)_PDB  ... small-to-large  \
# 186                            YB90A  ...          False
# 551                           TE487S  ...          False
# 1699                           KY96A  ...          False
# 3033                            YC5A  ...          False
# 3076                           RA65A  ...          False
# 3092                            YC8A  ...          False
# 3173                           KA66A  ...          False
# 3780     AA420T,AA547V,GA505E,MA418V  ...          False
# 4012  HH101Y,ML4L,NH31H,SH105T,TH28D  ...          False
# 4013  DH28T,HH31N,LL4M,TH105S,YH101H  ...          False
# 7                              YB90A  ...            NaN
# 84                             KY96A  ...            NaN
# 107                             YC5A  ...            NaN
# 110                             YC8A  ...            NaN
# 141                            RA65A  ...            NaN
# 142                            KA66A  ...            NaN
# 219      AA420T,AA547V,GA505E,MA418V  ...            NaN
# 243                           TE487S  ...            NaN
# 262   HH101Y,ML4L,NH31H,SH105T,TH28D  ...            NaN
# 263   DH28T,HH31N,LL4M,TH105S,YH101H  ...            NaN
#
#        type_of_change_infc        type_of_change_aa N_mut dG_bind_WT_mean  \
# 186       infc to non-infc                same type     1             NaN
# 551   non-infc to non-infc                same type     1             NaN
# 1699  non-infc to non-infc  positive to hydrophobic     1             NaN
# 3033      infc to non-infc                same type     1             NaN
# 3076      infc to non-infc  positive to hydrophobic     1             NaN
# 3092      infc to non-infc                same type     1             NaN
# 3173  non-infc to non-infc  positive to hydrophobic     1             NaN
# 3780                 mixed                    mixed    3+             NaN
# 4012                 mixed                    mixed    3+             NaN
# 4013                 mixed                    mixed    3+             NaN
# 7                      NaN                      NaN     1       -7.290668
# 84                     NaN                      NaN     1      -13.846823
# 107                    NaN                      NaN     1       -8.003645
# 110                    NaN                      NaN     1       -8.237212
# 141                    NaN                      NaN     1       -8.257064
# 142                    NaN                      NaN     1       -8.257064
# 219                    NaN                      NaN    3+       -7.100889
# 243                    NaN                      NaN     1      -10.474785
# 262                    NaN                      NaN    3+      -11.641537
# 263                    NaN                      NaN    3+      -13.436350
#
#       dG_bind_MUT_mean ddG_bind_mean  dG_bind_WT_std dG_bind_MUT_std  \
# 186                NaN           NaN             NaN             NaN
# 551                NaN           NaN             NaN             NaN
# 1699               NaN           NaN             NaN             NaN
# 3033               NaN           NaN             NaN             NaN
# 3076               NaN           NaN             NaN             NaN
# 3092               NaN           NaN             NaN             NaN
# 3173               NaN           NaN             NaN             NaN
# 3780               NaN           NaN             NaN             NaN
# 4012               NaN           NaN             NaN             NaN
# 4013               NaN           NaN             NaN             NaN
# 7            -5.214131      2.076537             NaN             NaN
# 84           -7.360418      6.486405             NaN             NaN
# 107                NaN           NaN             NaN             NaN
# 110                NaN           NaN             NaN             NaN
# 141          -5.102882      3.154183             NaN             NaN
# 142          -5.102882      3.154183             NaN             NaN
# 219                NaN           NaN             NaN             NaN
# 243                NaN           NaN             NaN             NaN
# 262         -13.436350     -1.794814             NaN             NaN
# 263         -11.641537      1.794814             NaN             NaN
#
#      ddG_bind_std
# 186           NaN
# 551           NaN
# 1699          NaN
# 3033          NaN
# 3076          NaN
# 3092          NaN
# 3173          NaN
# 3780          NaN
# 4012          NaN
# 4013          NaN
# 7             0.0
# 84            0.0
# 107           0.0
# 110           0.0
# 141           0.0
# 142           0.0
# 219           0.0
# 243           0.0
# 262           0.0
# 263           0.0
#
# [20 rows x 55 columns]

# %%
S2536 = pd.read_csv('/groups/sbinlab/panf/SKEMPIv2_benchmark/S2536.csv', sep=';', na_values='XXX')

# %%
S2536
# Out:
#                Entry   PDB Interacting Chains Mutation(s)  \
# 0                  1  1CSE                E:I       LI38G
# 1                  2  1CSE                E:I       LI38S
# 2                  3  1CSE                E:I       LI38P
# 3                  4  1CSE                E:I       LI38I
# 4                  5  1CSE                E:I       LI38D
# ...              ...   ...                ...         ...
# 2531            6933  4L0P                A:B       EA27K
# 2532            6934  4L0P                A:B       NA59S
# 2533            6935  4L0P                A:B       TA76Q
# 2534            6936  4L0P                A:B      TA140N
# 2535  7044,7045,7046  1YQV               HL:Y       RY45K
#
#      Mutation(s)_in_raw_pdb  Temperature Reference   DDGb  DDGb_SK1    cRSA  \
# 0                     LI45G        294.0   9048543  2.249     2.249   8.359
# 1                     LI45S        294.0   9048543  1.172     1.172   8.359
# 2                     LI45P        294.0   9048543  6.672     6.672   8.359
# 3                     LI45I        294.0   9048543  2.941     2.941   8.359
# 4                     LI45D        294.0   9048543  4.351     4.351   8.359
# ...                     ...          ...       ...    ...       ...     ...
# 2531                  EA53K        298.0  22242939  2.665       NaN   8.045
# 2532                  NA85S        298.0  22242939  0.314       NaN  21.901
# 2533                 TA102Q        298.0  22242939  1.472       NaN   0.000
# 2534                 TA166N        298.0  22242939  0.278       NaN  42.111
# 2535                  RY45K        297.0   9252107  1.867       NaN   3.279
#
#       ...  SAAMBE-3D  SAAMBE-3D_rev   NetTree NetTree_rev   FoldX FoldX_rev  \
# 0     ...   2.812825       0.530206  1.676192    1.527064  3.0042    3.3443
# 1     ...   1.543789       1.109185  2.706162    1.402388  3.2729   -2.5399
# 2     ...   5.933657       0.615902  3.116857    0.448269  3.1117   -1.8050
# 3     ...   2.560643       1.281160  1.463532    1.199537  2.5986   -0.9517
# 4     ...   4.143629       1.001774  3.296694    1.180625  2.6593   -1.9353
# ...   ...        ...            ...       ...         ...     ...       ...
# 2531  ...   1.417446       1.253170  2.783903    4.947306  4.0381   -3.6124
# 2532  ...  -0.016992       0.040266  1.115719    0.024264  0.0000   -0.1302
# 2533  ...   0.759861       0.816764  2.901882    1.486909  4.3408   -1.9547
# 2534  ...   0.140375       0.036820  2.027168   -0.102010  0.0000    0.0058
# 2535  ...   1.247154       1.001248  3.912203    1.456964  1.1376   -1.7402
#
#       BindProfX  BindProfX_rev  consensus  consensus_rev
# 0        2.6480        -0.1430   2.751777       0.162946
# 1        2.6710        -1.7170   2.494856      -0.688041
# 2        2.6960        -1.4480   3.973277      -1.205229
# 3        2.3510        -1.2850   2.098347      -0.502125
# 4        2.5390        -1.5260   3.235453      -0.653613
# ...         ...            ...        ...            ...
# 2531     1.9970        -1.1220   2.121806      -0.102740
# 2532     0.0000        -0.0330   0.234091      -0.068834
# 2533     2.1520        -0.5730   2.038568      -0.541753
# 2534     0.0000         0.0010   0.373818      -0.113174
# 2535     1.1376        -1.7402   1.751445      -0.304149
#
# [2536 rows x 37 columns]

# %%
S2536_sub = pd.merge(S2536, exp_cart_ddG_all_nb[['variant', 'mean_ddG', 'std_ddG',
                                              'mean_ddG_infc', 'std_ddG_infc', 'PDB_ID',
                                              'case_ID', 'Mutation(s)_PDB', 'ddG_bind', 
                                              'small-to-large', 'type_of_change_infc',
                                              'type_of_change_aa', 'N_mut',
                                              'multiple_measurements', 'no_proper_value',
                                              'Method',
                                              'LChains',	'RChains',	'Chains']], left_on=['PDB', 'Mutation(s)_in_raw_pdb'], right_on=['PDB_ID', 'Mutation(s)_PDB'], how='left')

# %%
S2536_sub
# Out:
#                Entry   PDB Interacting Chains Mutation(s)  \
# 0                  1  1CSE                E:I       LI38G
# 1                  2  1CSE                E:I       LI38S
# 2                  3  1CSE                E:I       LI38P
# 3                  4  1CSE                E:I       LI38I
# 4                  5  1CSE                E:I       LI38D
# ...              ...   ...                ...         ...
# 2532            6933  4L0P                A:B       EA27K
# 2533            6934  4L0P                A:B       NA59S
# 2534            6935  4L0P                A:B       TA76Q
# 2535            6936  4L0P                A:B      TA140N
# 2536  7044,7045,7046  1YQV               HL:Y       RY45K
#
#      Mutation(s)_in_raw_pdb  Temperature Reference   DDGb  DDGb_SK1    cRSA  \
# 0                     LI45G        294.0   9048543  2.249     2.249   8.359
# 1                     LI45S        294.0   9048543  1.172     1.172   8.359
# 2                     LI45P        294.0   9048543  6.672     6.672   8.359
# 3                     LI45I        294.0   9048543  2.941     2.941   8.359
# 4                     LI45D        294.0   9048543  4.351     4.351   8.359
# ...                     ...          ...       ...    ...       ...     ...
# 2532                  EA53K        298.0  22242939  2.665       NaN   8.045
# 2533                  NA85S        298.0  22242939  0.314       NaN  21.901
# 2534                 TA102Q        298.0  22242939  1.472       NaN   0.000
# 2535                 TA166N        298.0  22242939  0.278       NaN  42.111
# 2536                  RY45K        297.0   9252107  1.867       NaN   3.279
#
#       ...  small-to-large   type_of_change_infc        type_of_change_aa  \
# 0     ...           False      infc to non-infc   hydrophobic to special
# 1     ...           False      infc to non-infc     hydrophobic to polar
# 2     ...           False      infc to non-infc   hydrophobic to special
# 3     ...           False          infc to infc                same type
# 4     ...           False      infc to non-infc  hydrophobic to negative
# ...   ...             ...                   ...                      ...
# 2532  ...            True  non-infc to non-infc     negative to positive
# 2533  ...           False  non-infc to non-infc                same type
# 2534  ...            True  non-infc to non-infc                same type
# 2535  ...            True  non-infc to non-infc                same type
# 2536  ...           False      infc to non-infc                same type
#
#      N_mut multiple_measurements no_proper_value  Method  LChains  RChains  \
# 0        1                 False         Regular    IASP        E        I
# 1        1                 False         Regular    IASP        E        I
# 2        1                 False         Regular    IASP        E        I
# 3        1                 False         Regular    IASP        E        I
# 4        1                 False         Regular    IASP        E        I
# ...    ...                   ...             ...     ...      ...      ...
# 2532     1                 False         Regular   ELISA        A        B
# 2533     1                 False         Regular   ELISA        A        B
# 2534     1                 False         Regular   ELISA        A        B
# 2535     1                 False         Regular   ELISA        A        B
# 2536     1                  True         Regular     ITC       HL        Y
#
#       Chains
# 0         EI
# 1         EI
# 2         EI
# 3         EI
# 4         EI
# ...      ...
# 2532      AB
# 2533      AB
# 2534      AB
# 2535      AB
# 2536     HLY
#
# [2537 rows x 56 columns]

# %%
S2536_sub_flex = pd.merge(S2536_sub, exp_flex_ddG[['PDB_ID','case_ID', 'Mutation(s)_PDB', 'total_score']],
                     on =['PDB_ID','Mutation(s)_PDB'], how='left')

# %%
S2536_sub_flex.loc[S2536_sub_flex['total_score'].isna()]
# Out:
#                Entry   PDB Interacting Chains Mutation(s)  \
# 26                30  1Y3B                E:I       SI41E
# 28                33  1Y48                E:I       AI46R
# 33                43  1TM4                E:I       GI40M
# 34                44  1TM5                E:I       AI40M
# 35                45  1TM3                E:I       KI40M
# 38                48  1TO1                E:I       AI42Y
# 99           114,188  1BRS                A:D       DD39A
# 243              411  2WPT                A:B       DA30L
# 262          439,451  2WPT                A:B       SB67A
# 302              512  1EMV                A:B       TA36A
# 481         845,1262  1JTG                A:B       EA79K
# 496         947,5776  1JTG                A:B       EA85A
# 641             1283  2FTL                E:I       TI11A
# 642             1284  2FTL                E:I       GI12A
# 643             1285  2FTL                E:I       PI13A
# 644        1286,1344  2FTL                E:I       KI15A
# 645             1287  2FTL                E:I       RI17A
# 646             1288  2FTL                E:I       II18A
# 647             1289  2FTL                E:I       II19A
# 648             1290  2FTL                E:I       RI20A
# 649             1291  2FTL                E:I       FI33A
# 650             1292  2FTL                E:I       VI34A
# 651             1293  2FTL                E:I       YI35A
# 652             1294  2FTL                E:I       GI36A
# 653             1295  2FTL                E:I       GI37A
# 654             1296  2FTL                E:I       RI39A
# 655             1297  2FTL                E:I       KI46A
# 656             1343  2FTL                E:I       KI15G
# 657             1345  2FTL                E:I       KI15S
# 658             1346  2FTL                E:I       KI15V
# 659             1347  2FTL                E:I       KI15T
# 660             1348  2FTL                E:I       KI15D
# 661             1349  2FTL                E:I       KI15N
# 662             1350  2FTL                E:I       KI15M
# 663             1351  2FTL                E:I       KI15I
# 664             1352  2FTL                E:I       KI15L
# 665             1353  2FTL                E:I       KI15E
# 666             1354  2FTL                E:I       KI15Q
# 667             1355  2FTL                E:I       KI15H
# 668             1356  2FTL                E:I       KI15R
# 669             1357  2FTL                E:I       KI15F
# 670             1358  2FTL                E:I       KI15Y
# 671             1359  2FTL                E:I       KI15W
# 825        2080,3057  1DAN              HL:TU      VU113A
# 1034       2434,3242  1CHO              EFG:I       TI14E
# 2052       4728,4740  4I77               HL:Z      YH101A
# 2059       4735,4747  4I77               HL:Z       YL32A
# 2102  5327,5364,5441  3S9D                A:B       RA26A
# 2357            6667  1C1Y                A:B       DA38A
# 2358            6669  1LFD                A:B       YB32W
#
#      Mutation(s)_in_raw_pdb  Temperature  \
# 26                    SI60E       298.00
# 28                    AI65R       298.00
# 33                    GI59M       298.00
# 34                    AI59M       298.00
# 35                    KI59M       298.00
# 38                    AI61Y       298.00
# 99                    DD39A       298.00
# 243                   DA33L       298.00
# 262                   SB74A       298.00
# 302                   TA38A       298.00
# 481                  EA104K       298.00
# 496                  EA110A       297.00
# 641                   TI11A       295.00
# 642                   GI12A       295.00
# 643                   PI13A       295.00
# 644                   KI15A       295.00
# 645                   RI17A       295.00
# 646                   II18A       295.00
# 647                   II19A       295.00
# 648                   RI20A       295.00
# 649                   FI33A       295.00
# 650                   VI34A       295.00
# 651                   YI35A       295.00
# 652                   GI36A       295.00
# 653                   GI37A       295.00
# 654                   RI39A       295.00
# 655                   KI46A       295.00
# 656                   KI15G       295.00
# 657                   KI15S       295.00
# 658                   KI15V       295.00
# 659                   KI15T       295.00
# 660                   KI15D       295.00
# 661                   KI15N       295.00
# 662                   KI15M       295.00
# 663                   KI15I       295.00
# 664                   KI15L       295.00
# 665                   KI15E       295.00
# 666                   KI15Q       295.00
# 667                   KI15H       295.00
# 668                   KI15R       295.00
# 669                   KI15F       295.00
# 670                   KI15Y       295.00
# 671                   KI15W       295.00
# 825                  VU207A       298.00
# 1034                  TI17E       294.00
# 2052                  YH98A       304.00
# 2059                  YL28A       304.00
# 2102                  RA33A       298.00
# 2357                  DA38A       298.15
# 2358                 YB232W       298.15
#
#                                               Reference    DDGb DDGb_SK1  \
# 26                                             15865427  -2.747   -2.747
# 28                                             15865427  -3.754   -3.754
# 33                                             15504027  -2.232   -2.232
# 34                                             15504027  -1.027   -1.027
# 35                                             15504027  -1.093   -1.093
# 38                                             15504027  -2.980    -2.98
# 99    7739054,Water-mediated_interaction_at_a_protei...   6.790     6.79
# 243                                             9718299  -3.402   -3.402
# 262                                            18471830  -0.134   -0.134
# 302                                             9425068   0.900      0.9
# 481                                    9891008,21294157   3.239    4.233
# 496                                   17070843,24947275   1.378     4.06
# 641                                             8784199   4.050      XXX
# 642                                             8784199   4.347    4.347
# 643                                             8784199   4.050      XXX
# 644                                    8784199,10339415  10.290    10.29
# 645                                             8784199   4.050      XXX
# 646                                             8784199   4.969    4.969
# 647                                             8784199   4.050      XXX
# 648                                             8784199   4.050      XXX
# 649                                             8784199   4.050      XXX
# 650                                             8784199   4.050      XXX
# 651                                             8784199   4.050      XXX
# 652                                             8784199   4.891    2.191
# 653                                             8784199   4.050      XXX
# 654                                             8784199   4.050      XXX
# 655                                             8784199   4.050      XXX
# 656                                            10339415  12.222   12.222
# 657                                            10339415   7.643    7.643
# 658                                            10339415  11.633   11.633
# 659                                            10339415  10.486   10.486
# 660                                            10339415  11.382   11.382
# 661                                            10339415   7.949    7.949
# 662                                            10339415   7.612    7.612
# 663                                            10339415  11.054   11.054
# 664                                            10339415   8.771    8.771
# 665                                            10339415   9.325    9.325
# 666                                            10339415   9.272    9.272
# 667                                            10339415   8.689    8.689
# 668                                            10339415  -0.576      XXX
# 669                                            10339415   6.953    6.953
# 670                                            10339415   6.785    6.785
# 671                                            10339415   8.573    8.573
# 825                                     7947809,7654692   0.690     0.69
# 1034  11171964,Stephen_Ming-teh_Lu_PhD_Thesis_Purdue...   5.582    5.582
# 2052                                           23357170   1.654      XXX
# 2059                                           23357170   0.815      XXX
# 2102                         10556041,10984492,21854986   5.123      XXX
# 2357                                            8636102   2.620      XXX
# 2358                                            8636102  -0.211      XXX
#
#         cRSA  ...        type_of_change_aa  N_mut  multiple_measurements  \
# 26     7.029  ...        polar to negative      1                  False
# 28     6.889  ...  hydrophobic to positive      1                  False
# 33     9.414  ...   special to hydrophobic      1                  False
# 34     7.043  ...                same type      1                  False
# 35     8.284  ...  positive to hydrophobic      1                  False
# 38    14.288  ...                same type      1                  False
# 99     0.968  ...                      NaN    NaN                    NaN
# 243    1.225  ...  negative to hydrophobic      1                  False
# 262    4.186  ...                      NaN    NaN                    NaN
# 302   28.626  ...     polar to hydrophobic      1                  False
# 481    6.048  ...                      NaN    NaN                    NaN
# 496    7.146  ...                      NaN    NaN                    NaN
# 641   32.509  ...                      NaN      1                  False
# 642   17.480  ...   special to hydrophobic      1                  False
# 643   15.497  ...                      NaN      1                  False
# 644    0.000  ...  positive to hydrophobic      1                   True
# 645   18.087  ...                      NaN      1                  False
# 646    2.886  ...                same type      1                  False
# 647   36.631  ...                      NaN      1                  False
# 648   14.967  ...                      NaN      1                  False
# 649   10.175  ...                      NaN      1                  False
# 650   22.984  ...                      NaN      1                  False
# 651    6.456  ...                      NaN      1                  False
# 652    0.000  ...   special to hydrophobic      1                  False
# 653   15.318  ...                      NaN      1                  False
# 654   48.552  ...                      NaN      1                  False
# 655   70.643  ...                      NaN      1                  False
# 656    0.000  ...      positive to special      1                  False
# 657    0.000  ...        positive to polar      1                  False
# 658    0.000  ...  positive to hydrophobic      1                  False
# 659    0.000  ...        positive to polar      1                  False
# 660    0.000  ...     positive to negative      1                  False
# 661    0.000  ...        positive to polar      1                  False
# 662    0.000  ...  positive to hydrophobic      1                  False
# 663    0.000  ...  positive to hydrophobic      1                  False
# 664    0.000  ...  positive to hydrophobic      1                  False
# 665    0.000  ...     positive to negative      1                  False
# 666    0.000  ...        positive to polar      1                  False
# 667    0.000  ...                same type      1                  False
# 668    0.000  ...                same type      1                  False
# 669    0.000  ...  positive to hydrophobic      1                  False
# 670    0.000  ...  positive to hydrophobic      1                  False
# 671    0.000  ...  positive to hydrophobic      1                  False
# 825    2.422  ...                      NaN    NaN                    NaN
# 1034  16.190  ...                      NaN    NaN                    NaN
# 2052   8.374  ...                      NaN    NaN                    NaN
# 2059  35.450  ...                      NaN    NaN                    NaN
# 2102  10.682  ...                      NaN    NaN                    NaN
# 2357  11.212  ...                      NaN    NaN                    NaN
# 2358  89.958  ...                      NaN    NaN                    NaN
#
#                   no_proper_value Method LChains  RChains  Chains  case_ID_y  \
# 26                        Regular   IASP       E        I      EI    29_1Y3B
# 28                        Regular   IASP       E        I      EI    32_1Y48
# 33                        Regular   IASP       E        I      EI    38_1TM4
# 34                        Regular   IASP       E        I      EI    39_1TM5
# 35                        Regular   IASP       E        I      EI    40_1TM3
# 38                        Regular   IASP       E        I      EI    43_1TO1
# 99                            NaN    NaN     NaN      NaN     NaN        NaN
# 243                       Regular   SFFL       A        B      AB   360_2WPT
# 262                           NaN    NaN     NaN      NaN     NaN        NaN
# 302                       Regular   SFFL       A        B      AB   448_1EMV
# 481                           NaN    NaN     NaN      NaN     NaN        NaN
# 496                           NaN    NaN     NaN      NaN     NaN        NaN
# 641   MUT stronger than threshold   IASP     NaN      NaN     NaN  1162_2FTL
# 642                       Regular   IASP       E        I      EI  1163_2FTL
# 643   MUT stronger than threshold   IASP     NaN      NaN     NaN  1164_2FTL
# 644                       Regular   IASP       E        I      EI  1165_2FTL
# 645   MUT stronger than threshold   IASP     NaN      NaN     NaN  1166_2FTL
# 646                       Regular   IASP       E        I      EI  1167_2FTL
# 647   MUT stronger than threshold   IASP     NaN      NaN     NaN  1168_2FTL
# 648   MUT stronger than threshold   IASP     NaN      NaN     NaN  1169_2FTL
# 649   MUT stronger than threshold   IASP     NaN      NaN     NaN  1170_2FTL
# 650   MUT stronger than threshold   IASP     NaN      NaN     NaN  1171_2FTL
# 651   MUT stronger than threshold   IASP     NaN      NaN     NaN  1172_2FTL
# 652                       Regular   IASP       E        I      EI  1173_2FTL
# 653   MUT stronger than threshold   IASP     NaN      NaN     NaN  1174_2FTL
# 654   MUT stronger than threshold   IASP     NaN      NaN     NaN  1175_2FTL
# 655   MUT stronger than threshold   IASP     NaN      NaN     NaN  1176_2FTL
# 656                       Regular   IASP       E        I      EI  1208_2FTL
# 657                       Regular   IASP       E        I      EI  1209_2FTL
# 658                       Regular   IASP       E        I      EI  1210_2FTL
# 659                       Regular   IASP       E        I      EI  1211_2FTL
# 660                       Regular   IASP       E        I      EI  1212_2FTL
# 661                       Regular   IASP       E        I      EI  1213_2FTL
# 662                       Regular   IASP       E        I      EI  1214_2FTL
# 663                       Regular   IASP       E        I      EI  1215_2FTL
# 664                       Regular   IASP       E        I      EI  1216_2FTL
# 665                       Regular   IASP       E        I      EI  1217_2FTL
# 666                       Regular   IASP       E        I      EI  1218_2FTL
# 667                       Regular   IASP       E        I      EI  1219_2FTL
# 668                       Regular   IASP       E        I      EI  1220_2FTL
# 669                       Regular   IASP       E        I      EI  1221_2FTL
# 670                       Regular   IASP       E        I      EI  1222_2FTL
# 671                       Regular   IASP       E        I      EI  1223_2FTL
# 825                           NaN    NaN     NaN      NaN     NaN        NaN
# 1034                          NaN    NaN     NaN      NaN     NaN        NaN
# 2052                          NaN    NaN     NaN      NaN     NaN        NaN
# 2059                          NaN    NaN     NaN      NaN     NaN        NaN
# 2102                          NaN    NaN     NaN      NaN     NaN        NaN
# 2357                          NaN    NaN     NaN      NaN     NaN        NaN
# 2358                          NaN    NaN     NaN      NaN     NaN        NaN
#
#       total_score
# 26            NaN
# 28            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 38            NaN
# 99            NaN
# 243           NaN
# 262           NaN
# 302           NaN
# 481           NaN
# 496           NaN
# 641           NaN
# 642           NaN
# 643           NaN
# 644           NaN
# 645           NaN
# 646           NaN
# 647           NaN
# 648           NaN
# 649           NaN
# 650           NaN
# 651           NaN
# 652           NaN
# 653           NaN
# 654           NaN
# 655           NaN
# 656           NaN
# 657           NaN
# 658           NaN
# 659           NaN
# 660           NaN
# 661           NaN
# 662           NaN
# 663           NaN
# 664           NaN
# 665           NaN
# 666           NaN
# 667           NaN
# 668           NaN
# 669           NaN
# 670           NaN
# 671           NaN
# 825           NaN
# 1034          NaN
# 2052          NaN
# 2059          NaN
# 2102          NaN
# 2357          NaN
# 2358          NaN
#
# [50 rows x 58 columns]

# %%
method_list = ['mCSM-PPI2', 'MutaBind2','BeAtMuSiC','SSIPe','SAAMBE-3D', 'NetTree', 'FoldX', 'BindProfX', 'mean_ddG_infc', 'total_score']

# %%
for m in method_list:
    print(m)
    display(S2536_sub_flex.loc[S2536_sub_flex[m]=='XXX'])
# Out:
# mCSM-PPI2
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# MutaBind2
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# BeAtMuSiC
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# SSIPe
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# SAAMBE-3D
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# NetTree
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# FoldX
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# BindProfX
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# mean_ddG_infc
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]
# total_score
# Empty DataFrame
# Columns: [Entry, PDB, Interacting Chains, Mutation(s), Mutation(s)_in_raw_pdb, Temperature, Reference, DDGb, DDGb_SK1, cRSA, iRSA, ΔRSA, interface, region, sec_str, sec_str_grp, cRSA_rev, iRSA_rev, ΔRSA_rev, mCSM-PPI2, mCSM-PPI2_rev, MutaBind2, MutaBind2_rev, BeAtMuSiC, BeAtMuSiC_rev, SSIPe, SSIPe_rev, SAAMBE-3D, SAAMBE-3D_rev, NetTree, NetTree_rev, FoldX, FoldX_rev, BindProfX, BindProfX_rev, consensus, consensus_rev, variant, mean_ddG, std_ddG, mean_ddG_infc, std_ddG_infc, PDB_ID, case_ID_x, Mutation(s)_PDB, ddG_bind, small-to-large, type_of_change_infc, type_of_change_aa, N_mut, multiple_measurements, no_proper_value, Method, LChains, RChains, Chains, case_ID_y, total_score]
# Index: []
#
# [0 rows x 58 columns]

# %%
S2536_sub_flex.dropna(subset=method_list)
# Out:
#                Entry   PDB Interacting Chains Mutation(s)  \
# 0                  1  1CSE                E:I       LI38G
# 1                  2  1CSE                E:I       LI38S
# 2                  3  1CSE                E:I       LI38P
# 3                  4  1CSE                E:I       LI38I
# 4                  5  1CSE                E:I       LI38D
# ...              ...   ...                ...         ...
# 2532            6933  4L0P                A:B       EA27K
# 2533            6934  4L0P                A:B       NA59S
# 2534            6935  4L0P                A:B       TA76Q
# 2535            6936  4L0P                A:B      TA140N
# 2536  7044,7045,7046  1YQV               HL:Y       RY45K
#
#      Mutation(s)_in_raw_pdb  Temperature Reference   DDGb  DDGb_SK1    cRSA  \
# 0                     LI45G        294.0   9048543  2.249     2.249   8.359
# 1                     LI45S        294.0   9048543  1.172     1.172   8.359
# 2                     LI45P        294.0   9048543  6.672     6.672   8.359
# 3                     LI45I        294.0   9048543  2.941     2.941   8.359
# 4                     LI45D        294.0   9048543  4.351     4.351   8.359
# ...                     ...          ...       ...    ...       ...     ...
# 2532                  EA53K        298.0  22242939  2.665       NaN   8.045
# 2533                  NA85S        298.0  22242939  0.314       NaN  21.901
# 2534                 TA102Q        298.0  22242939  1.472       NaN   0.000
# 2535                 TA166N        298.0  22242939  0.278       NaN  42.111
# 2536                  RY45K        297.0   9252107  1.867       NaN   3.279
#
#       ...        type_of_change_aa  N_mut  multiple_measurements  \
# 0     ...   hydrophobic to special      1                  False
# 1     ...     hydrophobic to polar      1                  False
# 2     ...   hydrophobic to special      1                  False
# 3     ...                same type      1                  False
# 4     ...  hydrophobic to negative      1                  False
# ...   ...                      ...    ...                    ...
# 2532  ...     negative to positive      1                  False
# 2533  ...                same type      1                  False
# 2534  ...                same type      1                  False
# 2535  ...                same type      1                  False
# 2536  ...                same type      1                   True
#
#      no_proper_value Method LChains  RChains  Chains  case_ID_y  total_score
# 0            Regular   IASP       E        I      EI     0_1CSE      3.31973
# 1            Regular   IASP       E        I      EI     1_1CSE      2.32569
# 2            Regular   IASP       E        I      EI     2_1CSE      3.13394
# 3            Regular   IASP       E        I      EI     3_1CSE      0.01419
# 4            Regular   IASP       E        I      EI     4_1CSE      2.17061
# ...              ...    ...     ...      ...     ...        ...          ...
# 2532         Regular  ELISA       A        B      AB  6031_4L0P      2.83743
# 2533         Regular  ELISA       A        B      AB  6032_4L0P      0.13902
# 2534         Regular  ELISA       A        B      AB  6033_4L0P      0.66805
# 2535         Regular  ELISA       A        B      AB  6034_4L0P     -0.47818
# 2536         Regular    ITC      HL        Y     HLY  6136_1YQV      4.68996
#
# [2481 rows x 58 columns]

# %%
S2536_sub_flex_no_nan = S2536_sub_flex.dropna(subset=method_list)

for m in method_list:

    print(m)
    
    rp, pp = stats.pearsonr(S2536_sub_flex_no_nan['DDGb'], S2536_sub_flex_no_nan[m])
    print("Pearson's r: ", rp)
    
    rs, ps = stats.spearmanr(S2536_sub_flex_no_nan['DDGb'], S2536_sub_flex_no_nan[m])
    print("Spearman's r: ", rs)
    
    rmse = sqrt(mean_squared_error(S2536_sub_flex_no_nan['DDGb'], S2536_sub_flex_no_nan[m]))
    print("RMSE: ", rmse)
# Out:
# mCSM-PPI2
# Pearson's r:  0.9017332713868922
# Spearman's r:  0.8995568484195199
# RMSE:  0.9124757091508832
# MutaBind2
# Pearson's r:  0.8834803757421507
# Spearman's r:  0.8427335941261557
# RMSE:  0.9099244572690175
# BeAtMuSiC
# Pearson's r:  0.39686886586998543
# Spearman's r:  0.41248613035120707
# RMSE:  1.7273799483884016
# SSIPe
# Pearson's r:  0.5034671284415442
# Spearman's r:  0.441329538577453
# RMSE:  1.658831734412965
# SAAMBE-3D
# Pearson's r:  0.8732373736877087
# Spearman's r:  0.847123209076908
# RMSE:  0.9608455501759982
# NetTree
# Pearson's r:  0.17388282192081086
# Spearman's r:  0.2768266784946231
# RMSE:  2.2657919410568472
# FoldX
# Pearson's r:  0.44010173788482343
# Spearman's r:  0.4684175263050144
# RMSE:  1.9057225727858804
# BindProfX
# Pearson's r:  0.5242073474678963
# Spearman's r:  0.48455557728701015
# RMSE:  1.6002297724763999
# mean_ddG_infc
# Pearson's r:  0.5025308460625231
# Spearman's r:  0.4351018122945188
# RMSE:  1.7017588094106437
# total_score
# Pearson's r:  0.5107566221677047
# Spearman's r:  0.48646087709893454
# RMSE:  1.7103322642628467

# %%
for m in method_list:
    
    subset = S2536_sub_flex.dropna(subset=[m])

    print(m)
    
    rp, pp = stats.pearsonr(subset['DDGb'], subset[m])
    print("Pearson's r: ", rp)
    
    rs, ps = stats.spearmanr(subset['DDGb'], subset[m])
    print("Spearman's r: ", rs)
    
    rmse = sqrt(mean_squared_error(subset['DDGb'], subset[m]))
    print("RMSE: ", rmse)
# Out:
# mCSM-PPI2
# Pearson's r:  0.9065713815636292
# Spearman's r:  0.8987921003417888
# RMSE:  0.95333810992369
# MutaBind2
# Pearson's r:  0.8974975033794795
# Spearman's r:  0.8484939294642377
# RMSE:  0.9171401964416618
# BeAtMuSiC
# Pearson's r:  0.34536338259764543
# Spearman's r:  0.40152020893496715
# RMSE:  1.8982264004805318
# SSIPe
# Pearson's r:  0.5279010188135
# Spearman's r:  0.4579646086165386
# RMSE:  1.7577272577768066
# SAAMBE-3D
# Pearson's r:  0.87929243707728
# Spearman's r:  0.8458163459911525
# RMSE:  1.018349328771035
# NetTree
# Pearson's r:  0.15956498103321443
# Spearman's r:  0.2677507343376355
# RMSE:  2.367260419339713
# FoldX
# Pearson's r:  0.4432809438471133
# Spearman's r:  0.4764428781663325
# RMSE:  1.984842856033053
# BindProfX
# Pearson's r:  0.5621505835209354
# Spearman's r:  0.4969715206002239
# RMSE:  1.6548327190483967
# mean_ddG_infc
# Pearson's r:  0.4395449988788458
# Spearman's r:  0.4174675750859155
# RMSE:  1.9009102147445933
# total_score
# Pearson's r:  0.5106476805968843
# Spearman's r:  0.48689311879067615
# RMSE:  1.709351116939333

# %%
S2536_sub_flex_no_nan.loc[S2536_sub_flex_no_nan[m].dtype()]
# Out:
# 0       1.67619230251038
# 1       2.70616215945193
# 2       3.11685724477247
# 3       1.46353177685874
# 4       3.29669435320039
#               ...
# 2532       2.78390345392
# 2533       1.11571917641
# 2534       2.90188222636
# 2535       2.02716829893
# 2536       3.91220281236
# Name: NetTree, Length: 2487, dtype: object

# %%
S2536_sub[S2536_sub['ddG_bind'].isna()]
# Out:
#                Entry   PDB Interacting Chains Mutation(s)  \
# 99           114,188  1BRS                A:D       DD39A
# 262          439,451  2WPT                A:B       SB67A
# 481         845,1262  1JTG                A:B       EA79K
# 496         947,5776  1JTG                A:B       EA85A
# 825        2080,3057  1DAN              HL:TU      VU113A
# 1034       2434,3242  1CHO              EFG:I       TI14E
# 1772       3625,3634  1BD2             ABC:DE        YC5A
# 2052       4728,4740  4I77               HL:Z      YH101A
# 2059       4735,4747  4I77               HL:Z       YL32A
# 2102  5327,5364,5441  3S9D                A:B       RA26A
# 2357            6667  1C1Y                A:B       DA38A
# 2358            6669  1LFD                A:B       YB32W
#
#      Mutation(s)_in_raw_pdb  Temperature  \
# 99                    DD39A       298.00
# 262                   SB74A       298.00
# 481                  EA104K       298.00
# 496                  EA110A       297.00
# 825                  VU207A       298.00
# 1034                  TI17E       294.00
# 1772                   YC5A       298.00
# 2052                  YH98A       304.00
# 2059                  YL28A       304.00
# 2102                  RA33A       298.00
# 2357                  DA38A       298.15
# 2358                 YB232W       298.15
#
#                                               Reference   DDGb DDGb_SK1  \
# 99    7739054,Water-mediated_interaction_at_a_protei...  6.790     6.79
# 262                                            18471830 -0.134   -0.134
# 481                                    9891008,21294157  3.239    4.233
# 496                                   17070843,24947275  1.378     4.06
# 825                                     7947809,7654692  0.690     0.69
# 1034  11171964,Stephen_Ming-teh_Lu_PhD_Thesis_Purdue...  5.582    5.582
# 1772                                           23736024  3.340      XXX
# 2052                                           23357170  1.654      XXX
# 2059                                           23357170  0.815      XXX
# 2102                         10556041,10984492,21854986  5.123      XXX
# 2357                                            8636102  2.620      XXX
# 2358                                            8636102 -0.211      XXX
#
#         cRSA  ...  small-to-large  type_of_change_infc  type_of_change_aa  \
# 99     0.968  ...             NaN                  NaN                NaN
# 262    4.186  ...             NaN                  NaN                NaN
# 481    6.048  ...             NaN                  NaN                NaN
# 496    7.146  ...             NaN                  NaN                NaN
# 825    2.422  ...             NaN                  NaN                NaN
# 1034  16.190  ...             NaN                  NaN                NaN
# 1772   1.514  ...             NaN                  NaN                NaN
# 2052   8.374  ...             NaN                  NaN                NaN
# 2059  35.450  ...             NaN                  NaN                NaN
# 2102  10.682  ...             NaN                  NaN                NaN
# 2357  11.212  ...             NaN                  NaN                NaN
# 2358  89.958  ...             NaN                  NaN                NaN
#
#      N_mut multiple_measurements no_proper_value  Method  LChains  RChains  \
# 99     NaN                   NaN             NaN     NaN      NaN      NaN
# 262    NaN                   NaN             NaN     NaN      NaN      NaN
# 481    NaN                   NaN             NaN     NaN      NaN      NaN
# 496    NaN                   NaN             NaN     NaN      NaN      NaN
# 825    NaN                   NaN             NaN     NaN      NaN      NaN
# 1034   NaN                   NaN             NaN     NaN      NaN      NaN
# 1772     1                 False  no binding MUT     SPR      NaN      NaN
# 2052   NaN                   NaN             NaN     NaN      NaN      NaN
# 2059   NaN                   NaN             NaN     NaN      NaN      NaN
# 2102   NaN                   NaN             NaN     NaN      NaN      NaN
# 2357   NaN                   NaN             NaN     NaN      NaN      NaN
# 2358   NaN                   NaN             NaN     NaN      NaN      NaN
#
#       Chains
# 99       NaN
# 262      NaN
# 481      NaN
# 496      NaN
# 825      NaN
# 1034     NaN
# 1772     NaN
# 2052     NaN
# 2059     NaN
# 2102     NaN
# 2357     NaN
# 2358     NaN
#
# [12 rows x 56 columns]

# %%
S2536_sub.loc[(S2536_sub['no_proper_value']!='Regular')&(S2536_sub['no_proper_value'].isna())]
# Out:
#                Entry   PDB Interacting Chains Mutation(s)  \
# 99           114,188  1BRS                A:D       DD39A
# 262          439,451  2WPT                A:B       SB67A
# 481         845,1262  1JTG                A:B       EA79K
# 496         947,5776  1JTG                A:B       EA85A
# 825        2080,3057  1DAN              HL:TU      VU113A
# 1034       2434,3242  1CHO              EFG:I       TI14E
# 2052       4728,4740  4I77               HL:Z      YH101A
# 2059       4735,4747  4I77               HL:Z       YL32A
# 2102  5327,5364,5441  3S9D                A:B       RA26A
# 2357            6667  1C1Y                A:B       DA38A
# 2358            6669  1LFD                A:B       YB32W
#
#      Mutation(s)_in_raw_pdb  Temperature  \
# 99                    DD39A       298.00
# 262                   SB74A       298.00
# 481                  EA104K       298.00
# 496                  EA110A       297.00
# 825                  VU207A       298.00
# 1034                  TI17E       294.00
# 2052                  YH98A       304.00
# 2059                  YL28A       304.00
# 2102                  RA33A       298.00
# 2357                  DA38A       298.15
# 2358                 YB232W       298.15
#
#                                               Reference   DDGb DDGb_SK1  \
# 99    7739054,Water-mediated_interaction_at_a_protei...  6.790     6.79
# 262                                            18471830 -0.134   -0.134
# 481                                    9891008,21294157  3.239    4.233
# 496                                   17070843,24947275  1.378     4.06
# 825                                     7947809,7654692  0.690     0.69
# 1034  11171964,Stephen_Ming-teh_Lu_PhD_Thesis_Purdue...  5.582    5.582
# 2052                                           23357170  1.654      XXX
# 2059                                           23357170  0.815      XXX
# 2102                         10556041,10984492,21854986  5.123      XXX
# 2357                                            8636102  2.620      XXX
# 2358                                            8636102 -0.211      XXX
#
#         cRSA  ...  small-to-large  type_of_change_infc  type_of_change_aa  \
# 99     0.968  ...             NaN                  NaN                NaN
# 262    4.186  ...             NaN                  NaN                NaN
# 481    6.048  ...             NaN                  NaN                NaN
# 496    7.146  ...             NaN                  NaN                NaN
# 825    2.422  ...             NaN                  NaN                NaN
# 1034  16.190  ...             NaN                  NaN                NaN
# 2052   8.374  ...             NaN                  NaN                NaN
# 2059  35.450  ...             NaN                  NaN                NaN
# 2102  10.682  ...             NaN                  NaN                NaN
# 2357  11.212  ...             NaN                  NaN                NaN
# 2358  89.958  ...             NaN                  NaN                NaN
#
#      N_mut multiple_measurements no_proper_value  Method  LChains  RChains  \
# 99     NaN                   NaN             NaN     NaN      NaN      NaN
# 262    NaN                   NaN             NaN     NaN      NaN      NaN
# 481    NaN                   NaN             NaN     NaN      NaN      NaN
# 496    NaN                   NaN             NaN     NaN      NaN      NaN
# 825    NaN                   NaN             NaN     NaN      NaN      NaN
# 1034   NaN                   NaN             NaN     NaN      NaN      NaN
# 2052   NaN                   NaN             NaN     NaN      NaN      NaN
# 2059   NaN                   NaN             NaN     NaN      NaN      NaN
# 2102   NaN                   NaN             NaN     NaN      NaN      NaN
# 2357   NaN                   NaN             NaN     NaN      NaN      NaN
# 2358   NaN                   NaN             NaN     NaN      NaN      NaN
#
#       Chains
# 99       NaN
# 262      NaN
# 481      NaN
# 496      NaN
# 825      NaN
# 1034     NaN
# 2052     NaN
# 2059     NaN
# 2102     NaN
# 2357     NaN
# 2358     NaN
#
# [11 rows x 56 columns]

# %%
S2536_sub['no_proper_value'].unique()
# Out:
# array(['Regular', nan, 'MUT weaker than threshold',
#        'MUT stronger than threshold', 'no binding MUT',
#        'Both WT and MUT are out of range', 'WT stronger than threshold'],
#       dtype=object)

# %%
S2536_sub.dropna(subset=['DDGb'])
# Out:
#                Entry   PDB Interacting Chains Mutation(s)  \
# 0                  1  1CSE                E:I       LI38G
# 1                  2  1CSE                E:I       LI38S
# 2                  3  1CSE                E:I       LI38P
# 3                  4  1CSE                E:I       LI38I
# 4                  5  1CSE                E:I       LI38D
# ...              ...   ...                ...         ...
# 2532            6933  4L0P                A:B       EA27K
# 2533            6934  4L0P                A:B       NA59S
# 2534            6935  4L0P                A:B       TA76Q
# 2535            6936  4L0P                A:B      TA140N
# 2536  7044,7045,7046  1YQV               HL:Y       RY45K
#
#      Mutation(s)_in_raw_pdb  Temperature Reference   DDGb DDGb_SK1    cRSA  \
# 0                     LI45G        294.0   9048543  2.249    2.249   8.359
# 1                     LI45S        294.0   9048543  1.172    1.172   8.359
# 2                     LI45P        294.0   9048543  6.672    6.672   8.359
# 3                     LI45I        294.0   9048543  2.941    2.941   8.359
# 4                     LI45D        294.0   9048543  4.351    4.351   8.359
# ...                     ...          ...       ...    ...      ...     ...
# 2532                  EA53K        298.0  22242939  2.665      XXX   8.045
# 2533                  NA85S        298.0  22242939  0.314      XXX  21.901
# 2534                 TA102Q        298.0  22242939  1.472      XXX   0.000
# 2535                 TA166N        298.0  22242939  0.278      XXX  42.111
# 2536                  RY45K        297.0   9252107  1.867      XXX   3.279
#
#       ...  small-to-large   type_of_change_infc        type_of_change_aa  \
# 0     ...           False      infc to non-infc   hydrophobic to special
# 1     ...           False      infc to non-infc     hydrophobic to polar
# 2     ...           False      infc to non-infc   hydrophobic to special
# 3     ...           False          infc to infc                same type
# 4     ...           False      infc to non-infc  hydrophobic to negative
# ...   ...             ...                   ...                      ...
# 2532  ...            True  non-infc to non-infc     negative to positive
# 2533  ...           False  non-infc to non-infc                same type
# 2534  ...            True  non-infc to non-infc                same type
# 2535  ...            True  non-infc to non-infc                same type
# 2536  ...           False      infc to non-infc                same type
#
#      N_mut multiple_measurements no_proper_value  Method  LChains  RChains  \
# 0        1                 False         Regular    IASP        E        I
# 1        1                 False         Regular    IASP        E        I
# 2        1                 False         Regular    IASP        E        I
# 3        1                 False         Regular    IASP        E        I
# 4        1                 False         Regular    IASP        E        I
# ...    ...                   ...             ...     ...      ...      ...
# 2532     1                 False         Regular   ELISA        A        B
# 2533     1                 False         Regular   ELISA        A        B
# 2534     1                 False         Regular   ELISA        A        B
# 2535     1                 False         Regular   ELISA        A        B
# 2536     1                  True         Regular     ITC       HL        Y
#
#       Chains
# 0         EI
# 1         EI
# 2         EI
# 3         EI
# 4         EI
# ...      ...
# 2532      AB
# 2533      AB
# 2534      AB
# 2535      AB
# 2536     HLY
#
# [2537 rows x 56 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

df = S2536_sub.dropna(subset=['mean_ddG_infc'])

# Set up the JointGrid
g = sns.JointGrid(data=df, x='DDGb', y='mean_ddG_infc',
                  height=13,  # Adjust overall figure size
                  xlim=(-13, 13), ylim=(-13, 13))

#g = g.plot(sns.scatterplot, sns.kdeplot, alpha=0.5, linewidth=0, size=65)
g.plot_joint(sns.scatterplot, alpha=0.5, linewidth=0, s=85)
# g.plot_marginals(sns.kdeplot, fill=True, alpha=0.6, linewidth=0)
g.plot_marginals(sns.histplot, fill=True, alpha=0.8, linewidth=0, bins=300)

# Add labels and title
g.set_axis_labels(xlabel='Experimental binding ddG', ylabel='Predicted binding ddG', fontsize=25)
g.fig.suptitle('S2536', fontsize=28, y=1) # Adjust suptitle position


# Add the diagonal line
min_val = -15 - 1.5
max_val = 15 + 1.5
g.ax_joint.plot([min_val, max_val], [min_val, max_val], color='gray', ls='--', lw=1)

# Calculate and annotate Pearson correlation coefficients
r_p, p_p = stats.pearsonr(df['DDGb'], df['mean_ddG_infc'])
g.ax_joint.annotate(f"Pearson $\\rho = {r_p:.3f}$", xy=(-12, 12), fontsize = 25)

r_s, p_s = stats.spearmanr(df['DDGb'], df['mean_ddG_infc'])
g.ax_joint.annotate(f'Spearman $\\rho = {r_s:.3f}$', xy=(-12, 11), fontsize = 25)

rmse = sqrt(mean_squared_error(df['DDGb'], df['mean_ddG_infc']))
g.ax_joint.annotate(f'RMSE = {rmse:.3f}', xy=(-12, 10), fontsize = 25)

# # Add a legend to distinguish hue subgroups
# g.ax_joint.legend(title='Number of Mutations', fontsize=15, title_fontsize=18)

# Adjust layout and save the figure
plt.tight_layout(rect=[0, 0.03, 1, 1]) # Adjust rect to prevent suptitle overlap
plt.savefig('Figures/S2536.pdf', format='pdf')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

df = S2536_sub.dropna(subset=['mean_ddG'])

# Set up the JointGrid
g = sns.JointGrid(data=df, x='DDGb', y='mean_ddG',
                  height=13,  # Adjust overall figure size
                  xlim=(-13, 13), ylim=(-13, 13))

#g = g.plot(sns.scatterplot, sns.kdeplot, alpha=0.5, linewidth=0, size=65)
g.plot_joint(sns.scatterplot, alpha=0.5, linewidth=0, s=85)
# g.plot_marginals(sns.kdeplot, fill=True, alpha=0.6, linewidth=0)
g.plot_marginals(sns.histplot, fill=True, alpha=0.8, linewidth=0, bins=300)

# Add labels and title
g.set_axis_labels(xlabel='Experimental binding ddG', ylabel='Predicted binding ddG', fontsize=25)
g.fig.suptitle('S2536', fontsize=28, y=1) # Adjust suptitle position


# Add the diagonal line
min_val = -15 - 1.5
max_val = 15 + 1.5
g.ax_joint.plot([min_val, max_val], [min_val, max_val], color='gray', ls='--', lw=1)

# Calculate and annotate Pearson correlation coefficients
r_p, p_p = stats.pearsonr(df['DDGb'], df['mean_ddG'])
g.ax_joint.annotate(f"Pearson $\\rho = {r_p:.3f}$", xy=(-12, 12), fontsize = 25)

r_s, p_s = stats.spearmanr(df['DDGb'], df['mean_ddG'])
g.ax_joint.annotate(f'Spearman $\\rho = {r_s:.3f}$', xy=(-12, 11), fontsize = 25)

rmse = sqrt(mean_squared_error(df['DDGb'], df['mean_ddG']))
g.ax_joint.annotate(f'RMSE = {rmse:.3f}', xy=(-12, 10), fontsize = 25)

# # Add a legend to distinguish hue subgroups
# g.ax_joint.legend(title='Number of Mutations', fontsize=15, title_fontsize=18)

# Adjust layout and save the figure
plt.tight_layout(rect=[0, 0.03, 1, 1]) # Adjust rect to prevent suptitle overlap
#plt.savefig('Figures/S2536.pdf', format='pdf')

# %%
residue_asa_3 = {
    'GLY': 47.155,
    'ALA': 61.063,
    'SER': 69.073,
    'CYS': 78.62,
    'PRO': 81.03,
    'THR': 82.92,
    'ASP': 86.142,
    'VAL': 90.264,
    'ASN': 90.541,
    'GLU': 102.57,
    'ILE': 105.307,
    'LEU': 105.842,
    'GLN': 106.534,
    'HIS': 110.864,
    'MET': 112.01,
    'LYS': 120.502,
    'PHE': 124.714,
    'TYR': 130.885,
    'ARG': 138.595,
    'TRP': 148.915
}

residue_asa_1 = {
    'G': 47.155,
    'A': 61.063,
    'S': 69.073,
    'C': 78.62,
    'P': 81.03,
    'T': 82.92,
    'D': 86.142,
    'V': 90.264,
    'N': 90.541,
    'E': 102.57,
    'I': 105.307,
    'L': 105.842,
    'Q': 106.534,
    'H': 110.864,
    'M': 112.01,
    'K': 120.502,
    'F': 124.714,
    'Y': 130.885,
    'R': 138.595,
    'W': 148.915
}
